# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn import metrics
import pandas_datareader.data as web
from time import time

from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# #### (a) Get Data

# %%
# Read stock data use pandas_datareader.data from web
# Get Stock Data
stk_tickers = ['MSFT', 'IBM', 'GOOGL']
ccy_tickers = ['DEXJPUS', 'DEXUSUK']
idx_tickers = ['SP500', 'DJIA', 'VIXCLS']
stk_data = web.DataReader(stk_tickers, 'yahoo')
ccy_data = web.DataReader(ccy_tickers, 'fred')
idx_data = web.DataReader(idx_tickers, 'fred')

# %%
# Select columns
base = stk_data.loc[:, ('Adj Close', 'MSFT')]
X1 = stk_data.loc[:, ('Adj Close', ('GOOGL', 'IBM'))]
X2 = ccy_data
X3 = idx_data

# %% [markdown]
# #### (b) Standardized Data

# %%
# Standardized data (X1, X2, X3) with kept index (date)
standard_scaler = StandardScaler()
X1 = pd.DataFrame(standard_scaler.fit_transform(X1.values), index=X1.index, columns = X1.columns)
X2 = pd.DataFrame(standard_scaler.fit_transform(X2.values), index=X2.index, columns = X2.columns)
X3 = pd.DataFrame(standard_scaler.fit_transform(X3.values), index=X3.index, columns = X3.columns)

# %%
# Calculate ความแตกต่างของค่า ราคา 'Adj Close', 'MSFT’) ย้อนหลัง backHisotry วัน

backHistory = [30, 45, 60, 90, 180, 240]
BH1, BH2, BH3 = backHistory[1], backHistory[3], backHistory[4]
return_period = 2
Y = base.shift(-return_period)
X4_BH1 = base.diff( BH1).shift( - BH1)
X4_BH2 = base.diff( BH2).shift( - BH2)
X4_BH3 = base.diff( BH3).shift( - BH3)
X4 = pd.concat([X4_BH1, X4_BH2, X4_BH3], axis=1)
X4.columns = ['MSFT_3DT', 'MSFT_6DT', 'MSFT_12DT']
X4 = pd.DataFrame(standard_scaler.fit_transform(X4.values), index = X4.index,columns=X4.columns)

# %%
# Forming Dataset
X = pd.concat([X1, X2, X3, X4], axis=1)
dataset = pd.concat([Y, X], axis=1)

# %%
dataset
# Out:
#             (Adj Close, MSFT)  (Adj Close, GOOGL)  (Adj Close, IBM)   DEXJPUS  \
# 2017-10-09          71.808022           -1.084875         -0.413309       NaN
# 2017-10-10          72.465775           -1.092046         -0.336171  0.004572
# 2017-10-11          72.813446           -1.063665         -0.397327  0.028951
# 2017-10-12          72.963791           -1.063665         -0.438327  0.032608
# 2017-10-13          72.907417           -1.060135         -0.433464 -0.021025
# ...                       ...                 ...               ...       ...
# 2022-09-30         248.880005            0.379019          0.298717  3.973415
# 2022-10-03         249.199997            0.474100          0.547671       NaN
# 2022-10-04         246.789993            0.569500          0.915570       NaN
# 2022-10-05                NaN            0.562822          0.937699       NaN
# 2022-10-06                NaN            0.562504          0.614059       NaN
#
#              DEXUSUK     SP500      DJIA    VIXCLS  MSFT_3DT  MSFT_6DT  \
# 2017-10-09       NaN -1.237994 -1.438880 -1.192007  0.127784  0.065143
# 2017-10-10  0.199625 -1.229356 -1.421847 -1.220836  0.115510  0.092672
# 2017-10-11  0.191501 -1.222633 -1.411518 -1.247359  0.073382  0.040721
# 2017-10-12  0.133005 -1.228932 -1.419319 -1.240440  0.151489  0.023393
# 2017-10-13  0.344241 -1.225658 -1.411804 -1.275035  0.106757  0.098467
# ...              ...       ...       ...       ...       ...       ...
# 2022-09-30 -3.181782  0.283337  0.020590  1.263091       NaN       NaN
# 2022-10-03       NaN  0.418985  0.207875  1.087809       NaN       NaN
# 2022-10-04       NaN  0.583411  0.409854  0.969033       NaN       NaN
# 2022-10-05       NaN  0.572230  0.399467  0.909068       NaN       NaN
# 2022-10-06       NaN  0.515580  0.314575       NaN       NaN       NaN
#
#             MSFT_12DT
# 2017-10-09  -0.286224
# 2017-10-10  -0.257356
# 2017-10-11  -0.261280
# 2017-10-12  -0.242482
# 2017-10-13  -0.277571
# ...               ...
# 2022-09-30        NaN
# 2022-10-03        NaN
# 2022-10-04        NaN
# 2022-10-05        NaN
# 2022-10-06        NaN
#
# [1304 rows x 11 columns]

# %% [markdown]
# ### (c) Data Preparation

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1304 entries, 2017-10-09 to 2022-10-06
# Freq: B
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, MSFT)   1256 non-null   float64
#  1   (Adj Close, GOOGL)  1258 non-null   float64
#  2   (Adj Close, IBM)    1258 non-null   float64
#  3   DEXJPUS             1242 non-null   float64
#  4   DEXUSUK             1242 non-null   float64
#  5   SP500               1258 non-null   float64
#  6   DJIA                1258 non-null   float64
#  7   VIXCLS              1261 non-null   float64
#  8   MSFT_3DT            1213 non-null   float64
#  9   MSFT_6DT            1168 non-null   float64
#  10  MSFT_12DT           1078 non-null   float64
# dtypes: float64(11)
# memory usage: 122.2 KB

# %%
dataset.dropna(inplace=True)

dataset.describe()
# Out:
#        (Adj Close, MSFT)  (Adj Close, GOOGL)  (Adj Close, IBM)      DEXJPUS  \
# count        1061.000000         1061.000000       1061.000000  1061.000000
# mean          168.190780           -0.192291         -0.215152    -0.345302
# std            73.971521            0.939794          0.885424     0.339120
# min            72.465775           -1.095639         -3.293870    -1.169259
# 25%           103.008080           -0.871068         -0.707333    -0.586610
# 50%           145.731400           -0.657421         -0.250052    -0.336729
# 75%           217.759995            0.141950          0.268217    -0.107569
# max           340.882782            2.102209          1.886853     0.488489
#
#            DEXUSUK        SP500         DJIA       VIXCLS     MSFT_3DT  \
# count  1061.000000  1061.000000  1061.000000  1061.000000  1061.000000
# mean      0.158831    -0.183562    -0.169555    -0.109301     0.128483
# std       0.875196     0.952513     0.969700     1.029335     0.888353
# min      -2.600069    -1.687178    -2.459049    -1.329234    -3.747857
# 25%      -0.411335    -0.906628    -0.875276    -0.775713    -0.262242
# 50%       0.081008    -0.595358    -0.514972    -0.358265     0.100183
# 75%       0.890206     0.453799     0.384305     0.216013     0.540419
# max       2.014633     2.053207     1.996294     7.152327     2.549655
#
#           MSFT_6DT    MSFT_12DT
# count  1061.000000  1061.000000
# mean      0.137743     0.000898
# std       0.907923     0.995151
# min      -3.721285    -3.517306
# 25%      -0.225728    -0.393076
# 50%       0.094162     0.075891
# 75%       0.597251     0.626775
# max       2.204567     2.356101

# %%
# Assign X, Y
X = dataset.iloc[:, 1:]
Y = dataset.iloc[:, 0:1]

# %%
X.reset_index(inplace=True)
X.drop(columns=['index'], inplace=True)
X
# Out:
#       (Adj Close, GOOGL)  (Adj Close, IBM)   DEXJPUS   DEXUSUK     SP500  \
# 0              -1.092046         -0.336171  0.004572  0.199625 -1.229356
# 1              -1.063665         -0.397327  0.028951  0.191501 -1.222633
# 2              -1.063665         -0.438327  0.032608  0.133005 -1.228932
# 3              -1.060135         -0.433464 -0.021025  0.344241 -1.225658
# 4              -1.057782         -0.452227 -0.047842  0.313368 -1.219125
# ...                  ...               ...       ...       ...       ...
# 1056            1.834835          1.219405  0.320276  0.984450  1.950590
# 1057            1.744412          1.323413  0.237389  1.026697  1.852198
# 1058            1.772825          1.274520  0.216667  0.938953  1.857781
# 1059            1.662082          1.161623  0.303211  0.805711  1.732466
# 1060            1.634050          1.040725  0.264205  0.865832  1.667646
#
#           DJIA    VIXCLS  MSFT_3DT  MSFT_6DT  MSFT_12DT
# 0    -1.421847 -1.220836  0.115510  0.092672  -0.257356
# 1    -1.411518 -1.247359  0.073382  0.040721  -0.261280
# 2    -1.419319 -1.240440  0.151489  0.023393  -0.242482
# 3    -1.411804 -1.275035  0.106757  0.098467  -0.277571
# 4    -1.390946 -1.240440  0.068906  0.144406  -0.262946
# ...        ...       ...       ...       ...        ...
# 1056  1.871663 -0.351346 -1.355163 -2.824533  -3.192499
# 1057  1.828426 -0.041144 -0.670310 -2.326679  -2.602644
# 1058  1.779044 -0.170299 -0.697819 -2.426258  -2.525516
# 1059  1.646091  0.244842 -0.531027 -1.988078  -2.308140
# 1060  1.562939  0.367078 -0.309832 -1.720153  -2.393900
#
# [1061 rows x 10 columns]

# %%
Y.reset_index(inplace=True)
Y.drop(columns=['index'], inplace=True)
Y
# Out:
#       (Adj Close, MSFT)
# 0             72.465775
# 1             72.813446
# 2             72.963791
# 3             72.907417
# 4             72.926216
# ...                 ...
# 1056         308.186462
# 1057         300.685425
# 1058         301.361023
# 1059         299.642273
# 1060         294.108429
#
# [1061 rows x 1 columns]

# %%
sns.heatmap(X.corr())
# Out:
# <AxesSubplot:>

# %%
lower = pd.DataFrame(np.tril(X.corr(), -1), columns=X.corr().columns)
lower
# Out:
#    (Adj Close, GOOGL)  (Adj Close, IBM)   DEXJPUS   DEXUSUK     SP500  \
# 0            0.000000          0.000000  0.000000  0.000000  0.000000
# 1            0.502443          0.000000  0.000000  0.000000  0.000000
# 2            0.142627          0.266252  0.000000  0.000000  0.000000
# 3            0.492364          0.592318  0.088711  0.000000  0.000000
# 4            0.983325          0.522864  0.065211  0.495873  0.000000
# 5            0.954155          0.603744  0.110699  0.539900  0.983523
# 6            0.036919         -0.530827 -0.391689 -0.302625 -0.008897
# 7            0.006979         -0.029842 -0.311959  0.050360 -0.023139
# 8           -0.115311         -0.093508 -0.461014  0.003517 -0.095613
# 9           -0.407278         -0.402191 -0.598947 -0.211769 -0.325111
#
#        DJIA    VIXCLS  MSFT_3DT  MSFT_6DT  MSFT_12DT
# 0  0.000000  0.000000  0.000000  0.000000        0.0
# 1  0.000000  0.000000  0.000000  0.000000        0.0
# 2  0.000000  0.000000  0.000000  0.000000        0.0
# 3  0.000000  0.000000  0.000000  0.000000        0.0
# 4  0.000000  0.000000  0.000000  0.000000        0.0
# 5  0.000000  0.000000  0.000000  0.000000        0.0
# 6 -0.139544  0.000000  0.000000  0.000000        0.0
# 7 -0.039864  0.282019  0.000000  0.000000        0.0
# 8 -0.087408  0.323937  0.664654  0.000000        0.0
# 9 -0.314147  0.249140  0.413734  0.696994        0.0

# %%
sns.heatmap(lower, annot=True)
# Out:
# <AxesSubplot:>

# %%
to_drop = [column for column in lower if any(lower[column] > 0.9)]
to_drop
# Out:
# [('Adj Close', 'GOOGL'), 'SP500']

# %%
X.drop(to_drop, inplace=True, axis=1)
X
# Out:
#       (Adj Close, IBM)   DEXJPUS   DEXUSUK      DJIA    VIXCLS  MSFT_3DT  \
# 0            -0.336171  0.004572  0.199625 -1.421847 -1.220836  0.115510
# 1            -0.397327  0.028951  0.191501 -1.411518 -1.247359  0.073382
# 2            -0.438327  0.032608  0.133005 -1.419319 -1.240440  0.151489
# 3            -0.433464 -0.021025  0.344241 -1.411804 -1.275035  0.106757
# 4            -0.452227 -0.047842  0.313368 -1.390946 -1.240440  0.068906
# ...                ...       ...       ...       ...       ...       ...
# 1056          1.219405  0.320276  0.984450  1.871663 -0.351346 -1.355163
# 1057          1.323413  0.237389  1.026697  1.828426 -0.041144 -0.670310
# 1058          1.274520  0.216667  0.938953  1.779044 -0.170299 -0.697819
# 1059          1.161623  0.303211  0.805711  1.646091  0.244842 -0.531027
# 1060          1.040725  0.264205  0.865832  1.562939  0.367078 -0.309832
#
#       MSFT_6DT  MSFT_12DT
# 0     0.092672  -0.257356
# 1     0.040721  -0.261280
# 2     0.023393  -0.242482
# 3     0.098467  -0.277571
# 4     0.144406  -0.262946
# ...        ...        ...
# 1056 -2.824533  -3.192499
# 1057 -2.326679  -2.602644
# 1058 -2.426258  -2.525516
# 1059 -1.988078  -2.308140
# 1060 -1.720153  -2.393900
#
# [1061 rows x 8 columns]

# %%
seed = 50

# Option #1
Test_size = int(np.floor(0.3 * len(X)))
train_size = int(np.floor(0.7 * len(X)))
X_train, X_test = X[0:train_size], X[train_size:len(X)]
Y_train, Y_test = Y[0:train_size], Y[train_size:len(X)]

# Option #2
# X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.3, random_state=seed)

# %% [markdown]
#  ## Prepare Parameter Dictionary and Linear Regression(), SVR()

# %% [markdown]
# #### (a) Create Model List and Parameter Dictionary

# %%
# Create Model List
regression = { 'LR': LinearRegression(), 'SVR': SVR(), }

# %%
# Create Parameter Dictionary for Linear Regression
fit_intercept = [True, False]
normalize = [True, False]
params_LR = dict( fit_intercept = fit_intercept, normalize = normalize)

# %%
# Create Parameter Dictionary for SVR
kernel = ['linear', 'rbf', 'poly']
C_list = [10, 100]
ep_list = [0.1, 1, 5]
gamma = [0.01, 0.1] 
degree = [2, 3]

params_SVR = dict( kernel = kernel, C = C_list, epsilon = ep_list, gamma = gamma, degree = degree )

# %% [markdown]
# #### GridSearchCV() -> (a)

# %%
for EST in regression:
    model = regression[EST]
    if (EST == 'LR'):
        params = params_LR
    else:
        params = params_SVR    
    grid = GridSearchCV(estimator=model, 
                        n_jobs = 1,
                        verbose = 10,
                        cv = 4,
                        scoring = 'neg_mean_squared_error',
                        param_grid = params )
    grid_result = grid.fit(X_train, Y_train)
# Out:
# Fitting 4 folds for each of 4 candidates, totalling 16 fits
# [CV 1/4; 1/4] START fit_intercept=True, normalize=True..........................
# [CV 1/4; 1/4] END fit_intercept=True, normalize=True;, score=-534.384 total time=   0.0s
# [CV 2/4; 1/4] START fit_intercept=True, normalize=True..........................
# [CV 2/4; 1/4] END fit_intercept=True, normalize=True;, score=-808.010 total time=   0.0s
# [CV 3/4; 1/4] START fit_intercept=True, normalize=True..........................
# [CV 3/4; 1/4] END fit_intercept=True, normalize=True;, score=-1626.168 total time=   0.0s
# [CV 4/4; 1/4] START fit_intercept=True, normalize=True..........................
# [CV 4/4; 1/4] END fit_intercept=True, normalize=True;, score=-3101.402 total time=   0.0s
# [CV 1/4; 2/4] START fit_intercept=True, normalize=False.........................
# [CV 1/4; 2/4] END fit_intercept=True, normalize=False;, score=-534.384 total time=   0.0s
# [CV 2/4; 2/4] START fit_intercept=True, normalize=False.........................
# [CV 2/4; 2/4] END fit_intercept=True, normalize=False;, score=-808.010 total time=   0.0s
# [CV 3/4; 2/4] START fit_intercept=True, normalize=False.........................
# [CV 3/4; 2/4] END fit_intercept=True, normalize=False;, score=-1626.168 total time=   0.0s
# [CV 4/4; 2/4] START fit_intercept=True, normalize=False.........................
# [CV 4/4; 2/4] END fit_intercept=True, normalize=False;, score=-3101.402 total time=   0.0s
# [CV 1/4; 3/4] START fit_intercept=False, normalize=True.........................
# [CV 1/4; 3/4] END fit_intercept=False, normalize=True;, score=-9790.403 total time=   0.0s
# [CV 2/4; 3/4] START fit_intercept=False, normalize=True.........................
# [CV 2/4; 3/4] END fit_intercept=False, normalize=True;, score=-1734.164 total time=   0.0s
# [CV 3/4; 3/4] START fit_intercept=False, normalize=True.........................
# [CV 3/4; 3/4] END fit_intercept=False, normalize=True;, score=-7267.370 total time=   0.0s
# [CV 4/4; 3/4] START fit_intercept=False, normalize=True.........................
# [CV 4/4; 3/4] END fit_intercept=False, normalize=True;, score=-20596.397 total time=   0.0s
# [CV 1/4; 4/4] START fit_intercept=False, normalize=False........................
# [CV 1/4; 4/4] END fit_intercept=False, normalize=False;, score=-9790.403 total time=   0.0s
# [CV 2/4; 4/4] START fit_intercept=False, normalize=False........................
# [CV 2/4; 4/4] END fit_intercept=False, normalize=False;, score=-1734.164 total time=   0.0s
# [CV 3/4; 4/4] START fit_intercept=False, normalize=False........................
# [CV 3/4; 4/4] END fit_intercept=False, normalize=False;, score=-7267.370 total time=   0.0s
# [CV 4/4; 4/4] START fit_intercept=False, normalize=False........................
# [CV 4/4; 4/4] END fit_intercept=False, normalize=False;, score=-20596.397 total time=   0.0s
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# [CV 1/4; 1/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=linear.....
# [CV 1/4; 1/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=linear;, score=-1197.694 total time=   0.0s
# [CV 2/4; 1/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=linear.....
# [CV 2/4; 1/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=linear;, score=-660.225 total time=   0.0s
# [CV 3/4; 1/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=linear.....
# [CV 3/4; 1/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=linear;, score=-1709.697 total time=   0.0s
# [CV 4/4; 1/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=linear.....
# [CV 4/4; 1/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=linear;, score=-3054.796 total time=   0.0s
# [CV 1/4; 2/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf........
# [CV 1/4; 2/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-615.381 total time=   0.0s
# [CV 2/4; 2/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf........
# [CV 2/4; 2/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-568.865 total time=   0.0s
# [CV 3/4; 2/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf........
# [CV 3/4; 2/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-209.730 total time=   0.0s
# [CV 4/4; 2/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf........
# [CV 4/4; 2/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-4515.585 total time=   0.0s
# [CV 1/4; 3/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=poly.......
# [CV 1/4; 3/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=poly;, score=-2197.819 total time=   0.0s
# [CV 2/4; 3/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=poly.......
# [CV 2/4; 3/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=poly;, score=-825.748 total time=   0.0s
# [CV 3/4; 3/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=poly.......
# [CV 3/4; 3/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=poly;, score=-1070.851 total time=   0.0s
# [CV 4/4; 3/72] START C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=poly.......
# [CV 4/4; 3/72] END C=10, degree=2, epsilon=0.1, gamma=0.01, kernel=poly;, score=-6807.447 total time=   0.0s
# [CV 1/4; 4/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=linear......
# [CV 1/4; 4/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=linear;, score=-1197.694 total time=   0.0s
# [CV 2/4; 4/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=linear......
# [CV 2/4; 4/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=linear;, score=-660.225 total time=   0.0s
# [CV 3/4; 4/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=linear......
# [CV 3/4; 4/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=linear;, score=-1709.697 total time=   0.0s
# [CV 4/4; 4/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=linear......
# [CV 4/4; 4/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=linear;, score=-3054.796 total time=   0.0s
# [CV 1/4; 5/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf.........
# [CV 1/4; 5/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-896.156 total time=   0.0s
# [CV 2/4; 5/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf.........
# [CV 2/4; 5/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-1043.555 total time=   0.0s
# [CV 3/4; 5/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf.........
# [CV 3/4; 5/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-359.465 total time=   0.0s
# [CV 4/4; 5/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf.........
# [CV 4/4; 5/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-3785.582 total time=   0.0s
# [CV 1/4; 6/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=poly........
# [CV 1/4; 6/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=poly;, score=-1074.931 total time=   0.0s
# [CV 2/4; 6/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=poly........
# [CV 2/4; 6/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=poly;, score=-975.491 total time=   0.0s
# [CV 3/4; 6/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=poly........
# [CV 3/4; 6/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=poly;, score=-214.875 total time=   0.0s
# [CV 4/4; 6/72] START C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=poly........
# [CV 4/4; 6/72] END C=10, degree=2, epsilon=0.1, gamma=0.1, kernel=poly;, score=-6201.649 total time=   0.0s
# [CV 1/4; 7/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=linear.......
# [CV 1/4; 7/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=linear;, score=-1173.465 total time=   0.0s
# [CV 2/4; 7/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=linear.......
# [CV 2/4; 7/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=linear;, score=-665.514 total time=   0.0s
# [CV 3/4; 7/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=linear.......
# [CV 3/4; 7/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=linear;, score=-1639.238 total time=   0.0s
# [CV 4/4; 7/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=linear.......
# [CV 4/4; 7/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=linear;, score=-3067.160 total time=   0.0s
# [CV 1/4; 8/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=rbf..........
# [CV 1/4; 8/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=rbf;, score=-637.193 total time=   0.0s
# [CV 2/4; 8/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=rbf..........
# [CV 2/4; 8/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=rbf;, score=-570.139 total time=   0.0s
# [CV 3/4; 8/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=rbf..........
# [CV 3/4; 8/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=rbf;, score=-214.365 total time=   0.0s
# [CV 4/4; 8/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=rbf..........
# [CV 4/4; 8/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=rbf;, score=-4446.555 total time=   0.0s
# [CV 1/4; 9/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=poly.........
# [CV 1/4; 9/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=poly;, score=-2174.187 total time=   0.0s
# [CV 2/4; 9/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=poly.........
# [CV 2/4; 9/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=poly;, score=-815.327 total time=   0.0s
# [CV 3/4; 9/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=poly.........
# [CV 3/4; 9/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=poly;, score=-1051.500 total time=   0.0s
# [CV 4/4; 9/72] START C=10, degree=2, epsilon=1, gamma=0.01, kernel=poly.........
# [CV 4/4; 9/72] END C=10, degree=2, epsilon=1, gamma=0.01, kernel=poly;, score=-6772.902 total time=   0.0s
# [CV 1/4; 10/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=linear.......
# [CV 1/4; 10/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=linear;, score=-1173.465 total time=   0.0s
# [CV 2/4; 10/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=linear.......
# [CV 2/4; 10/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=linear;, score=-665.514 total time=   0.0s
# [CV 3/4; 10/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=linear.......
# [CV 3/4; 10/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=linear;, score=-1639.238 total time=   0.0s
# [CV 4/4; 10/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=linear.......
# [CV 4/4; 10/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=linear;, score=-3067.160 total time=   0.0s
# [CV 1/4; 11/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=rbf..........
# [CV 1/4; 11/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=rbf;, score=-936.880 total time=   0.0s
# [CV 2/4; 11/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=rbf..........
# [CV 2/4; 11/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=rbf;, score=-1063.251 total time=   0.0s
# [CV 3/4; 11/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=rbf..........
# [CV 3/4; 11/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=rbf;, score=-365.681 total time=   0.0s
# [CV 4/4; 11/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=rbf..........
# [CV 4/4; 11/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=rbf;, score=-3839.910 total time=   0.0s
# [CV 1/4; 12/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=poly.........
# [CV 1/4; 12/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=poly;, score=-1082.102 total time=   0.0s
# [CV 2/4; 12/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=poly.........
# [CV 2/4; 12/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=poly;, score=-971.993 total time=   0.0s
# [CV 3/4; 12/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=poly.........
# [CV 3/4; 12/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=poly;, score=-215.954 total time=   0.0s
# [CV 4/4; 12/72] START C=10, degree=2, epsilon=1, gamma=0.1, kernel=poly.........
# [CV 4/4; 12/72] END C=10, degree=2, epsilon=1, gamma=0.1, kernel=poly;, score=-5982.520 total time=   0.0s
# [CV 1/4; 13/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=linear......
# [CV 1/4; 13/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=linear;, score=-1070.740 total time=   0.0s
# [CV 2/4; 13/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=linear......
# [CV 2/4; 13/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=linear;, score=-787.381 total time=   0.0s
# [CV 3/4; 13/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=linear......
# [CV 3/4; 13/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=linear;, score=-1633.565 total time=   0.0s
# [CV 4/4; 13/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=linear......
# [CV 4/4; 13/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=linear;, score=-3076.149 total time=   0.0s
# [CV 1/4; 14/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=rbf.........
# [CV 1/4; 14/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=rbf;, score=-811.601 total time=   0.0s
# [CV 2/4; 14/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=rbf.........
# [CV 2/4; 14/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=rbf;, score=-572.506 total time=   0.0s
# [CV 3/4; 14/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=rbf.........
# [CV 3/4; 14/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=rbf;, score=-211.981 total time=   0.0s
# [CV 4/4; 14/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=rbf.........
# [CV 4/4; 14/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=rbf;, score=-4353.998 total time=   0.0s
# [CV 1/4; 15/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=poly........
# [CV 1/4; 15/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=poly;, score=-2096.961 total time=   0.0s
# [CV 2/4; 15/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=poly........
# [CV 2/4; 15/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=poly;, score=-760.783 total time=   0.0s
# [CV 3/4; 15/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=poly........
# [CV 3/4; 15/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=poly;, score=-1051.487 total time=   0.0s
# [CV 4/4; 15/72] START C=10, degree=2, epsilon=5, gamma=0.01, kernel=poly........
# [CV 4/4; 15/72] END C=10, degree=2, epsilon=5, gamma=0.01, kernel=poly;, score=-6575.844 total time=   0.0s
# [CV 1/4; 16/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=linear.......
# [CV 1/4; 16/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=linear;, score=-1070.740 total time=   0.0s
# [CV 2/4; 16/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=linear.......
# [CV 2/4; 16/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=linear;, score=-787.381 total time=   0.0s
# [CV 3/4; 16/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=linear.......
# [CV 3/4; 16/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=linear;, score=-1633.565 total time=   0.0s
# [CV 4/4; 16/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=linear.......
# [CV 4/4; 16/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=linear;, score=-3076.149 total time=   0.0s
# [CV 1/4; 17/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=rbf..........
# [CV 1/4; 17/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=rbf;, score=-1009.782 total time=   0.0s
# [CV 2/4; 17/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=rbf..........
# [CV 2/4; 17/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=rbf;, score=-1147.544 total time=   0.0s
# [CV 3/4; 17/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=rbf..........
# [CV 3/4; 17/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=rbf;, score=-370.635 total time=   0.0s
# [CV 4/4; 17/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=rbf..........
# [CV 4/4; 17/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=rbf;, score=-4043.102 total time=   0.0s
# [CV 1/4; 18/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=poly.........
# [CV 1/4; 18/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=poly;, score=-1156.223 total time=   0.0s
# [CV 2/4; 18/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=poly.........
# [CV 2/4; 18/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=poly;, score=-1030.144 total time=   0.0s
# [CV 3/4; 18/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=poly.........
# [CV 3/4; 18/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=poly;, score=-207.652 total time=   0.0s
# [CV 4/4; 18/72] START C=10, degree=2, epsilon=5, gamma=0.1, kernel=poly.........
# [CV 4/4; 18/72] END C=10, degree=2, epsilon=5, gamma=0.1, kernel=poly;, score=-6641.780 total time=   0.0s
# [CV 1/4; 19/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=linear....
# [CV 1/4; 19/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=linear;, score=-1197.694 total time=   0.0s
# [CV 2/4; 19/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=linear....
# [CV 2/4; 19/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=linear;, score=-660.225 total time=   0.0s
# [CV 3/4; 19/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=linear....
# [CV 3/4; 19/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=linear;, score=-1709.697 total time=   0.0s
# [CV 4/4; 19/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=linear....
# [CV 4/4; 19/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=linear;, score=-3054.796 total time=   0.0s
# [CV 1/4; 20/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf.......
# [CV 1/4; 20/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-615.381 total time=   0.0s
# [CV 2/4; 20/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf.......
# [CV 2/4; 20/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-568.865 total time=   0.0s
# [CV 3/4; 20/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf.......
# [CV 3/4; 20/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-209.730 total time=   0.0s
# [CV 4/4; 20/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf.......
# [CV 4/4; 20/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-4515.585 total time=   0.0s
# [CV 1/4; 21/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=poly......
# [CV 1/4; 21/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=poly;, score=-2247.474 total time=   0.0s
# [CV 2/4; 21/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=poly......
# [CV 2/4; 21/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=poly;, score=-844.919 total time=   0.0s
# [CV 3/4; 21/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=poly......
# [CV 3/4; 21/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=poly;, score=-1067.600 total time=   0.0s
# [CV 4/4; 21/72] START C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=poly......
# [CV 4/4; 21/72] END C=10, degree=3, epsilon=0.1, gamma=0.01, kernel=poly;, score=-6751.689 total time=   0.0s
# [CV 1/4; 22/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=linear.....
# [CV 1/4; 22/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=linear;, score=-1197.694 total time=   0.0s
# [CV 2/4; 22/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=linear.....
# [CV 2/4; 22/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=linear;, score=-660.225 total time=   0.0s
# [CV 3/4; 22/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=linear.....
# [CV 3/4; 22/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=linear;, score=-1709.697 total time=   0.0s
# [CV 4/4; 22/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=linear.....
# [CV 4/4; 22/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=linear;, score=-3054.796 total time=   0.0s
# [CV 1/4; 23/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf........
# [CV 1/4; 23/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-896.156 total time=   0.0s
# [CV 2/4; 23/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf........
# [CV 2/4; 23/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-1043.555 total time=   0.0s
# [CV 3/4; 23/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf........
# [CV 3/4; 23/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-359.465 total time=   0.0s
# [CV 4/4; 23/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf........
# [CV 4/4; 23/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-3785.582 total time=   0.0s
# [CV 1/4; 24/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=poly.......
# [CV 1/4; 24/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=poly;, score=-1805.828 total time=   0.0s
# [CV 2/4; 24/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=poly.......
# [CV 2/4; 24/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=poly;, score=-663.588 total time=   0.0s
# [CV 3/4; 24/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=poly.......
# [CV 3/4; 24/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=poly;, score=-565.305 total time=   0.0s
# [CV 4/4; 24/72] START C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=poly.......
# [CV 4/4; 24/72] END C=10, degree=3, epsilon=0.1, gamma=0.1, kernel=poly;, score=-5843.815 total time=   0.0s
# [CV 1/4; 25/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=linear......
# [CV 1/4; 25/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=linear;, score=-1173.465 total time=   0.0s
# [CV 2/4; 25/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=linear......
# [CV 2/4; 25/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=linear;, score=-665.514 total time=   0.0s
# [CV 3/4; 25/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=linear......
# [CV 3/4; 25/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=linear;, score=-1639.238 total time=   0.0s
# [CV 4/4; 25/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=linear......
# [CV 4/4; 25/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=linear;, score=-3067.160 total time=   0.0s
# [CV 1/4; 26/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=rbf.........
# [CV 1/4; 26/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=rbf;, score=-637.193 total time=   0.0s
# [CV 2/4; 26/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=rbf.........
# [CV 2/4; 26/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=rbf;, score=-570.139 total time=   0.0s
# [CV 3/4; 26/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=rbf.........
# [CV 3/4; 26/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=rbf;, score=-214.365 total time=   0.0s
# [CV 4/4; 26/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=rbf.........
# [CV 4/4; 26/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=rbf;, score=-4446.555 total time=   0.0s
# [CV 1/4; 27/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=poly........
# [CV 1/4; 27/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=poly;, score=-2233.725 total time=   0.0s
# [CV 2/4; 27/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=poly........
# [CV 2/4; 27/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=poly;, score=-835.311 total time=   0.0s
# [CV 3/4; 27/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=poly........
# [CV 3/4; 27/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=poly;, score=-1056.764 total time=   0.0s
# [CV 4/4; 27/72] START C=10, degree=3, epsilon=1, gamma=0.01, kernel=poly........
# [CV 4/4; 27/72] END C=10, degree=3, epsilon=1, gamma=0.01, kernel=poly;, score=-6731.333 total time=   0.0s
# [CV 1/4; 28/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=linear.......
# [CV 1/4; 28/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=linear;, score=-1173.465 total time=   0.0s
# [CV 2/4; 28/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=linear.......
# [CV 2/4; 28/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=linear;, score=-665.514 total time=   0.0s
# [CV 3/4; 28/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=linear.......
# [CV 3/4; 28/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=linear;, score=-1639.238 total time=   0.0s
# [CV 4/4; 28/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=linear.......
# [CV 4/4; 28/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=linear;, score=-3067.160 total time=   0.0s
# [CV 1/4; 29/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=rbf..........
# [CV 1/4; 29/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=rbf;, score=-936.880 total time=   0.0s
# [CV 2/4; 29/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=rbf..........
# [CV 2/4; 29/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=rbf;, score=-1063.251 total time=   0.0s
# [CV 3/4; 29/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=rbf..........
# [CV 3/4; 29/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=rbf;, score=-365.681 total time=   0.0s
# [CV 4/4; 29/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=rbf..........
# [CV 4/4; 29/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=rbf;, score=-3839.910 total time=   0.0s
# [CV 1/4; 30/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=poly.........
# [CV 1/4; 30/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=poly;, score=-1801.157 total time=   0.0s
# [CV 2/4; 30/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=poly.........
# [CV 2/4; 30/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=poly;, score=-652.611 total time=   0.0s
# [CV 3/4; 30/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=poly.........
# [CV 3/4; 30/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=poly;, score=-564.828 total time=   0.0s
# [CV 4/4; 30/72] START C=10, degree=3, epsilon=1, gamma=0.1, kernel=poly.........
# [CV 4/4; 30/72] END C=10, degree=3, epsilon=1, gamma=0.1, kernel=poly;, score=-5992.655 total time=   0.0s
# [CV 1/4; 31/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=linear......
# [CV 1/4; 31/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=linear;, score=-1070.740 total time=   0.0s
# [CV 2/4; 31/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=linear......
# [CV 2/4; 31/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=linear;, score=-787.381 total time=   0.0s
# [CV 3/4; 31/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=linear......
# [CV 3/4; 31/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=linear;, score=-1633.565 total time=   0.0s
# [CV 4/4; 31/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=linear......
# [CV 4/4; 31/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=linear;, score=-3076.149 total time=   0.0s
# [CV 1/4; 32/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=rbf.........
# [CV 1/4; 32/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=rbf;, score=-811.601 total time=   0.0s
# [CV 2/4; 32/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=rbf.........
# [CV 2/4; 32/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=rbf;, score=-572.506 total time=   0.0s
# [CV 3/4; 32/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=rbf.........
# [CV 3/4; 32/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=rbf;, score=-211.981 total time=   0.0s
# [CV 4/4; 32/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=rbf.........
# [CV 4/4; 32/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=rbf;, score=-4353.998 total time=   0.0s
# [CV 1/4; 33/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=poly........
# [CV 1/4; 33/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=poly;, score=-2205.501 total time=   0.0s
# [CV 2/4; 33/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=poly........
# [CV 2/4; 33/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=poly;, score=-807.864 total time=   0.0s
# [CV 3/4; 33/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=poly........
# [CV 3/4; 33/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=poly;, score=-1017.775 total time=   0.0s
# [CV 4/4; 33/72] START C=10, degree=3, epsilon=5, gamma=0.01, kernel=poly........
# [CV 4/4; 33/72] END C=10, degree=3, epsilon=5, gamma=0.01, kernel=poly;, score=-6588.239 total time=   0.0s
# [CV 1/4; 34/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=linear.......
# [CV 1/4; 34/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=linear;, score=-1070.740 total time=   0.0s
# [CV 2/4; 34/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=linear.......
# [CV 2/4; 34/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=linear;, score=-787.381 total time=   0.0s
# [CV 3/4; 34/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=linear.......
# [CV 3/4; 34/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=linear;, score=-1633.565 total time=   0.0s
# [CV 4/4; 34/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=linear.......
# [CV 4/4; 34/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=linear;, score=-3076.149 total time=   0.0s
# [CV 1/4; 35/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=rbf..........
# [CV 1/4; 35/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=rbf;, score=-1009.782 total time=   0.0s
# [CV 2/4; 35/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=rbf..........
# [CV 2/4; 35/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=rbf;, score=-1147.544 total time=   0.0s
# [CV 3/4; 35/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=rbf..........
# [CV 3/4; 35/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=rbf;, score=-370.635 total time=   0.0s
# [CV 4/4; 35/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=rbf..........
# [CV 4/4; 35/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=rbf;, score=-4043.102 total time=   0.0s
# [CV 1/4; 36/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=poly.........
# [CV 1/4; 36/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=poly;, score=-1661.103 total time=   0.0s
# [CV 2/4; 36/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=poly.........
# [CV 2/4; 36/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=poly;, score=-628.131 total time=   0.0s
# [CV 3/4; 36/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=poly.........
# [CV 3/4; 36/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=poly;, score=-513.838 total time=   0.0s
# [CV 4/4; 36/72] START C=10, degree=3, epsilon=5, gamma=0.1, kernel=poly.........
# [CV 4/4; 36/72] END C=10, degree=3, epsilon=5, gamma=0.1, kernel=poly;, score=-6087.848 total time=   0.0s
# [CV 1/4; 37/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=linear...
# [CV 1/4; 37/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=linear;, score=-1172.733 total time=   0.0s
# [CV 2/4; 37/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=linear...
# [CV 2/4; 37/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=linear;, score=-637.548 total time=   0.0s
# [CV 3/4; 37/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=linear...
# [CV 3/4; 37/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=linear;, score=-1713.238 total time=   0.0s
# [CV 4/4; 37/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=linear...
# [CV 4/4; 37/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=linear;, score=-3063.322 total time=   0.0s
# [CV 1/4; 38/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf......
# [CV 1/4; 38/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-989.793 total time=   0.0s
# [CV 2/4; 38/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf......
# [CV 2/4; 38/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-967.577 total time=   0.0s
# [CV 3/4; 38/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf......
# [CV 3/4; 38/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-883.508 total time=   0.0s
# [CV 4/4; 38/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf......
# [CV 4/4; 38/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-3300.622 total time=   0.0s
# [CV 1/4; 39/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=poly.....
# [CV 1/4; 39/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=poly;, score=-1870.047 total time=   0.0s
# [CV 2/4; 39/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=poly.....
# [CV 2/4; 39/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=poly;, score=-713.296 total time=   0.0s
# [CV 3/4; 39/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=poly.....
# [CV 3/4; 39/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=poly;, score=-888.547 total time=   0.0s
# [CV 4/4; 39/72] START C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=poly.....
# [CV 4/4; 39/72] END C=100, degree=2, epsilon=0.1, gamma=0.01, kernel=poly;, score=-6974.368 total time=   0.0s
# [CV 1/4; 40/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=linear....
# [CV 1/4; 40/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=linear;, score=-1172.733 total time=   0.0s
# [CV 2/4; 40/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=linear....
# [CV 2/4; 40/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=linear;, score=-637.548 total time=   0.0s
# [CV 3/4; 40/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=linear....
# [CV 3/4; 40/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=linear;, score=-1713.238 total time=   0.0s
# [CV 4/4; 40/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=linear....
# [CV 4/4; 40/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=linear;, score=-3063.322 total time=   0.0s
# [CV 1/4; 41/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf.......
# [CV 1/4; 41/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-703.108 total time=   0.0s
# [CV 2/4; 41/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf.......
# [CV 2/4; 41/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-888.881 total time=   0.0s
# [CV 3/4; 41/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf.......
# [CV 3/4; 41/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-270.088 total time=   0.0s
# [CV 4/4; 41/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf.......
# [CV 4/4; 41/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-3440.981 total time=   0.0s
# [CV 1/4; 42/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=poly......
# [CV 1/4; 42/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=poly;, score=-1123.517 total time=   0.0s
# [CV 2/4; 42/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=poly......
# [CV 2/4; 42/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=poly;, score=-934.472 total time=   0.0s
# [CV 3/4; 42/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=poly......
# [CV 3/4; 42/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=poly;, score=-570.626 total time=   0.0s
# [CV 4/4; 42/72] START C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=poly......
# [CV 4/4; 42/72] END C=100, degree=2, epsilon=0.1, gamma=0.1, kernel=poly;, score=-4414.778 total time=   0.0s
# [CV 1/4; 43/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=linear.....
# [CV 1/4; 43/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=linear;, score=-1156.571 total time=   0.0s
# [CV 2/4; 43/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=linear.....
# [CV 2/4; 43/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=linear;, score=-638.665 total time=   0.0s
# [CV 3/4; 43/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=linear.....
# [CV 3/4; 43/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=linear;, score=-1673.039 total time=   0.0s
# [CV 4/4; 43/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=linear.....
# [CV 4/4; 43/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=linear;, score=-3069.651 total time=   0.0s
# [CV 1/4; 44/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=rbf........
# [CV 1/4; 44/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=rbf;, score=-989.133 total time=   0.0s
# [CV 2/4; 44/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=rbf........
# [CV 2/4; 44/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=rbf;, score=-976.558 total time=   0.0s
# [CV 3/4; 44/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=rbf........
# [CV 3/4; 44/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=rbf;, score=-873.546 total time=   0.0s
# [CV 4/4; 44/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=rbf........
# [CV 4/4; 44/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=rbf;, score=-3313.814 total time=   0.0s
# [CV 1/4; 45/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=poly.......
# [CV 1/4; 45/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=poly;, score=-1875.200 total time=   0.0s
# [CV 2/4; 45/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=poly.......
# [CV 2/4; 45/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=poly;, score=-709.656 total time=   0.0s
# [CV 3/4; 45/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=poly.......
# [CV 3/4; 45/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=poly;, score=-882.522 total time=   0.0s
# [CV 4/4; 45/72] START C=100, degree=2, epsilon=1, gamma=0.01, kernel=poly.......
# [CV 4/4; 45/72] END C=100, degree=2, epsilon=1, gamma=0.01, kernel=poly;, score=-6902.329 total time=   0.0s
# [CV 1/4; 46/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=linear......
# [CV 1/4; 46/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=linear;, score=-1156.571 total time=   0.0s
# [CV 2/4; 46/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=linear......
# [CV 2/4; 46/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=linear;, score=-638.665 total time=   0.0s
# [CV 3/4; 46/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=linear......
# [CV 3/4; 46/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=linear;, score=-1673.039 total time=   0.0s
# [CV 4/4; 46/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=linear......
# [CV 4/4; 46/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=linear;, score=-3069.651 total time=   0.0s
# [CV 1/4; 47/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=rbf.........
# [CV 1/4; 47/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=rbf;, score=-763.335 total time=   0.0s
# [CV 2/4; 47/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=rbf.........
# [CV 2/4; 47/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=rbf;, score=-849.334 total time=   0.0s
# [CV 3/4; 47/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=rbf.........
# [CV 3/4; 47/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=rbf;, score=-278.418 total time=   0.0s
# [CV 4/4; 47/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=rbf.........
# [CV 4/4; 47/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=rbf;, score=-3229.060 total time=   0.0s
# [CV 1/4; 48/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=poly........
# [CV 1/4; 48/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=poly;, score=-1106.592 total time=   0.0s
# [CV 2/4; 48/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=poly........
# [CV 2/4; 48/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=poly;, score=-890.797 total time=   0.0s
# [CV 3/4; 48/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=poly........
# [CV 3/4; 48/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=poly;, score=-585.471 total time=   0.0s
# [CV 4/4; 48/72] START C=100, degree=2, epsilon=1, gamma=0.1, kernel=poly........
# [CV 4/4; 48/72] END C=100, degree=2, epsilon=1, gamma=0.1, kernel=poly;, score=-4439.967 total time=   0.0s
# [CV 1/4; 49/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=linear.....
# [CV 1/4; 49/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=linear;, score=-1048.475 total time=   0.0s
# [CV 2/4; 49/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=linear.....
# [CV 2/4; 49/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=linear;, score=-771.591 total time=   0.0s
# [CV 3/4; 49/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=linear.....
# [CV 3/4; 49/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=linear;, score=-1725.211 total time=   0.0s
# [CV 4/4; 49/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=linear.....
# [CV 4/4; 49/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=linear;, score=-3170.504 total time=   0.0s
# [CV 1/4; 50/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=rbf........
# [CV 1/4; 50/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=rbf;, score=-948.897 total time=   0.0s
# [CV 2/4; 50/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=rbf........
# [CV 2/4; 50/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=rbf;, score=-1019.412 total time=   0.0s
# [CV 3/4; 50/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=rbf........
# [CV 3/4; 50/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=rbf;, score=-888.589 total time=   0.0s
# [CV 4/4; 50/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=rbf........
# [CV 4/4; 50/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=rbf;, score=-3570.090 total time=   0.0s
# [CV 1/4; 51/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=poly.......
# [CV 1/4; 51/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=poly;, score=-1838.860 total time=   0.0s
# [CV 2/4; 51/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=poly.......
# [CV 2/4; 51/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=poly;, score=-687.707 total time=   0.0s
# [CV 3/4; 51/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=poly.......
# [CV 3/4; 51/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=poly;, score=-817.574 total time=   0.0s
# [CV 4/4; 51/72] START C=100, degree=2, epsilon=5, gamma=0.01, kernel=poly.......
# [CV 4/4; 51/72] END C=100, degree=2, epsilon=5, gamma=0.01, kernel=poly;, score=-6649.260 total time=   0.0s
# [CV 1/4; 52/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=linear......
# [CV 1/4; 52/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=linear;, score=-1048.475 total time=   0.0s
# [CV 2/4; 52/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=linear......
# [CV 2/4; 52/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=linear;, score=-771.591 total time=   0.0s
# [CV 3/4; 52/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=linear......
# [CV 3/4; 52/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=linear;, score=-1725.211 total time=   0.0s
# [CV 4/4; 52/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=linear......
# [CV 4/4; 52/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=linear;, score=-3170.504 total time=   0.0s
# [CV 1/4; 53/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=rbf.........
# [CV 1/4; 53/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=rbf;, score=-731.768 total time=   0.0s
# [CV 2/4; 53/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=rbf.........
# [CV 2/4; 53/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=rbf;, score=-992.305 total time=   0.0s
# [CV 3/4; 53/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=rbf.........
# [CV 3/4; 53/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=rbf;, score=-247.112 total time=   0.0s
# [CV 4/4; 53/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=rbf.........
# [CV 4/4; 53/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=rbf;, score=-3586.325 total time=   0.0s
# [CV 1/4; 54/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=poly........
# [CV 1/4; 54/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=poly;, score=-1003.735 total time=   0.0s
# [CV 2/4; 54/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=poly........
# [CV 2/4; 54/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=poly;, score=-1028.465 total time=   0.0s
# [CV 3/4; 54/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=poly........
# [CV 3/4; 54/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=poly;, score=-572.760 total time=   0.0s
# [CV 4/4; 54/72] START C=100, degree=2, epsilon=5, gamma=0.1, kernel=poly........
# [CV 4/4; 54/72] END C=100, degree=2, epsilon=5, gamma=0.1, kernel=poly;, score=-4828.613 total time=   0.0s
# [CV 1/4; 55/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=linear...
# [CV 1/4; 55/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=linear;, score=-1172.733 total time=   0.0s
# [CV 2/4; 55/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=linear...
# [CV 2/4; 55/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=linear;, score=-637.548 total time=   0.0s
# [CV 3/4; 55/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=linear...
# [CV 3/4; 55/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=linear;, score=-1713.238 total time=   0.0s
# [CV 4/4; 55/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=linear...
# [CV 4/4; 55/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=linear;, score=-3063.322 total time=   0.0s
# [CV 1/4; 56/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf......
# [CV 1/4; 56/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-989.793 total time=   0.0s
# [CV 2/4; 56/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf......
# [CV 2/4; 56/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-967.577 total time=   0.0s
# [CV 3/4; 56/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf......
# [CV 3/4; 56/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-883.508 total time=   0.0s
# [CV 4/4; 56/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf......
# [CV 4/4; 56/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-3300.622 total time=   0.0s
# [CV 1/4; 57/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=poly.....
# [CV 1/4; 57/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=poly;, score=-2232.115 total time=   0.0s
# [CV 2/4; 57/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=poly.....
# [CV 2/4; 57/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=poly;, score=-831.735 total time=   0.0s
# [CV 3/4; 57/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=poly.....
# [CV 3/4; 57/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=poly;, score=-1080.224 total time=   0.0s
# [CV 4/4; 57/72] START C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=poly.....
# [CV 4/4; 57/72] END C=100, degree=3, epsilon=0.1, gamma=0.01, kernel=poly;, score=-6769.833 total time=   0.0s
# [CV 1/4; 58/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=linear....
# [CV 1/4; 58/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=linear;, score=-1172.733 total time=   0.0s
# [CV 2/4; 58/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=linear....
# [CV 2/4; 58/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=linear;, score=-637.548 total time=   0.0s
# [CV 3/4; 58/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=linear....
# [CV 3/4; 58/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=linear;, score=-1713.238 total time=   0.0s
# [CV 4/4; 58/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=linear....
# [CV 4/4; 58/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=linear;, score=-3063.322 total time=   0.0s
# [CV 1/4; 59/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf.......
# [CV 1/4; 59/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-703.108 total time=   0.0s
# [CV 2/4; 59/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf.......
# [CV 2/4; 59/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-888.881 total time=   0.0s
# [CV 3/4; 59/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf.......
# [CV 3/4; 59/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-270.088 total time=   0.0s
# [CV 4/4; 59/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf.......
# [CV 4/4; 59/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-3440.981 total time=   0.0s
# [CV 1/4; 60/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=poly......
# [CV 1/4; 60/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=poly;, score=-803.124 total time=   0.0s
# [CV 2/4; 60/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=poly......
# [CV 2/4; 60/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=poly;, score=-719.646 total time=   0.0s
# [CV 3/4; 60/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=poly......
# [CV 3/4; 60/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=poly;, score=-256.076 total time=   0.0s
# [CV 4/4; 60/72] START C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=poly......
# [CV 4/4; 60/72] END C=100, degree=3, epsilon=0.1, gamma=0.1, kernel=poly;, score=-5077.233 total time=   0.0s
# [CV 1/4; 61/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=linear.....
# [CV 1/4; 61/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=linear;, score=-1156.571 total time=   0.0s
# [CV 2/4; 61/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=linear.....
# [CV 2/4; 61/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=linear;, score=-638.665 total time=   0.0s
# [CV 3/4; 61/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=linear.....
# [CV 3/4; 61/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=linear;, score=-1673.039 total time=   0.0s
# [CV 4/4; 61/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=linear.....
# [CV 4/4; 61/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=linear;, score=-3069.651 total time=   0.0s
# [CV 1/4; 62/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=rbf........
# [CV 1/4; 62/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=rbf;, score=-989.133 total time=   0.0s
# [CV 2/4; 62/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=rbf........
# [CV 2/4; 62/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=rbf;, score=-976.558 total time=   0.0s
# [CV 3/4; 62/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=rbf........
# [CV 3/4; 62/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=rbf;, score=-873.546 total time=   0.0s
# [CV 4/4; 62/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=rbf........
# [CV 4/4; 62/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=rbf;, score=-3313.814 total time=   0.0s
# [CV 1/4; 63/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=poly.......
# [CV 1/4; 63/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=poly;, score=-2217.999 total time=   0.0s
# [CV 2/4; 63/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=poly.......
# [CV 2/4; 63/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=poly;, score=-828.723 total time=   0.0s
# [CV 3/4; 63/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=poly.......
# [CV 3/4; 63/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=poly;, score=-1063.938 total time=   0.0s
# [CV 4/4; 63/72] START C=100, degree=3, epsilon=1, gamma=0.01, kernel=poly.......
# [CV 4/4; 63/72] END C=100, degree=3, epsilon=1, gamma=0.01, kernel=poly;, score=-6741.343 total time=   0.0s
# [CV 1/4; 64/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=linear......
# [CV 1/4; 64/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=linear;, score=-1156.571 total time=   0.0s
# [CV 2/4; 64/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=linear......
# [CV 2/4; 64/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=linear;, score=-638.665 total time=   0.0s
# [CV 3/4; 64/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=linear......
# [CV 3/4; 64/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=linear;, score=-1673.039 total time=   0.0s
# [CV 4/4; 64/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=linear......
# [CV 4/4; 64/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=linear;, score=-3069.651 total time=   0.0s
# [CV 1/4; 65/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=rbf.........
# [CV 1/4; 65/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=rbf;, score=-763.335 total time=   0.0s
# [CV 2/4; 65/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=rbf.........
# [CV 2/4; 65/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=rbf;, score=-849.334 total time=   0.0s
# [CV 3/4; 65/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=rbf.........
# [CV 3/4; 65/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=rbf;, score=-278.418 total time=   0.0s
# [CV 4/4; 65/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=rbf.........
# [CV 4/4; 65/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=rbf;, score=-3229.060 total time=   0.0s
# [CV 1/4; 66/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=poly........
# [CV 1/4; 66/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=poly;, score=-810.655 total time=   0.0s
# [CV 2/4; 66/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=poly........
# [CV 2/4; 66/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=poly;, score=-756.755 total time=   0.0s
# [CV 3/4; 66/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=poly........
# [CV 3/4; 66/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=poly;, score=-255.693 total time=   0.0s
# [CV 4/4; 66/72] START C=100, degree=3, epsilon=1, gamma=0.1, kernel=poly........
# [CV 4/4; 66/72] END C=100, degree=3, epsilon=1, gamma=0.1, kernel=poly;, score=-5753.282 total time=   0.0s
# [CV 1/4; 67/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=linear.....
# [CV 1/4; 67/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=linear;, score=-1048.475 total time=   0.0s
# [CV 2/4; 67/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=linear.....
# [CV 2/4; 67/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=linear;, score=-771.591 total time=   0.0s
# [CV 3/4; 67/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=linear.....
# [CV 3/4; 67/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=linear;, score=-1725.211 total time=   0.0s
# [CV 4/4; 67/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=linear.....
# [CV 4/4; 67/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=linear;, score=-3170.504 total time=   0.0s
# [CV 1/4; 68/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=rbf........
# [CV 1/4; 68/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=rbf;, score=-948.897 total time=   0.0s
# [CV 2/4; 68/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=rbf........
# [CV 2/4; 68/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=rbf;, score=-1019.412 total time=   0.0s
# [CV 3/4; 68/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=rbf........
# [CV 3/4; 68/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=rbf;, score=-888.589 total time=   0.0s
# [CV 4/4; 68/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=rbf........
# [CV 4/4; 68/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=rbf;, score=-3570.090 total time=   0.0s
# [CV 1/4; 69/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=poly.......
# [CV 1/4; 69/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=poly;, score=-2140.378 total time=   0.0s
# [CV 2/4; 69/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=poly.......
# [CV 2/4; 69/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=poly;, score=-773.536 total time=   0.0s
# [CV 3/4; 69/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=poly.......
# [CV 3/4; 69/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=poly;, score=-1039.707 total time=   0.0s
# [CV 4/4; 69/72] START C=100, degree=3, epsilon=5, gamma=0.01, kernel=poly.......
# [CV 4/4; 69/72] END C=100, degree=3, epsilon=5, gamma=0.01, kernel=poly;, score=-6546.323 total time=   0.0s
# [CV 1/4; 70/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=linear......
# [CV 1/4; 70/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=linear;, score=-1048.475 total time=   0.0s
# [CV 2/4; 70/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=linear......
# [CV 2/4; 70/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=linear;, score=-771.591 total time=   0.0s
# [CV 3/4; 70/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=linear......
# [CV 3/4; 70/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=linear;, score=-1725.211 total time=   0.0s
# [CV 4/4; 70/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=linear......
# [CV 4/4; 70/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=linear;, score=-3170.504 total time=   0.0s
# [CV 1/4; 71/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=rbf.........
# [CV 1/4; 71/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=rbf;, score=-731.768 total time=   0.0s
# [CV 2/4; 71/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=rbf.........
# [CV 2/4; 71/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=rbf;, score=-992.305 total time=   0.0s
# [CV 3/4; 71/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=rbf.........
# [CV 3/4; 71/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=rbf;, score=-247.112 total time=   0.0s
# [CV 4/4; 71/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=rbf.........
# [CV 4/4; 71/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=rbf;, score=-3586.325 total time=   0.0s
# [CV 1/4; 72/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=poly........
# [CV 1/4; 72/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=poly;, score=-924.265 total time=   0.0s
# [CV 2/4; 72/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=poly........
# [CV 2/4; 72/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=poly;, score=-813.966 total time=   0.0s
# [CV 3/4; 72/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=poly........
# [CV 3/4; 72/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=poly;, score=-221.535 total time=   0.0s
# [CV 4/4; 72/72] START C=100, degree=3, epsilon=5, gamma=0.1, kernel=poly........
# [CV 4/4; 72/72] END C=100, degree=3, epsilon=5, gamma=0.1, kernel=poly;, score=-12345.412 total time=   0.0s

# %% [markdown]
# #### GridSearchCV() -> (b)

# %%
# Show Best Parameters for both models
print('Best params: ',grid_result.best_params_)
print('Best score: ', grid_result.best_score_)
# Out:
# Best params:  {'C': 100, 'degree': 2, 'epsilon': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Best score:  -1280.0366982681471

# %%
# Show Score for each parameter combination for both model
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
data_zipped = zip(means, stds, params)

# for mean, stdev, param in data_zipped:
  # print("%f (%f) with: %r" % (mean, stdev, param))

data_linear = [{'means': means[i], 'stds': stds[i]} for i in range(len(params)) if params[i]['kernel'] == 'linear' ]
data_rbf = [{'means': means[i], 'stds': stds[i]} for i in range(len(params)) if params[i]['kernel'] == 'rbf' ]
data_poly = [{'means': means[i], 'stds': stds[i]} for i in range(len(params)) if params[i]['kernel'] == 'poly' ]

# %%
df_linear = pd.DataFrame(data=data_linear)
df_linear.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df_rbf = pd.DataFrame(data=data_rbf)
df_rbf.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df_poly = pd.DataFrame(data=data_poly)
df_poly.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 6.3 Prepare Parameter Dicionary and LinearRegression(), SVR()

# %% [markdown]
# #### (a) Create Model List and Parameter Dictionary

# %%
# Create Model List
regression = { 'LR': LinearRegression(), 'SVR': SVR(), }

# %%
# Create Parameter Dictionary for Linear Regression
fit_intercept = [True, False]
normalize = [True, False]
params_LR = dict( fit_intercept = fit_intercept, normalize = normalize)

# %%
# Create Parameter Dictionary for SVR
kernel = ['linear', 'rbf', 'poly']
C_list = list(np.linspace(0.1, 150, 5, dtype = float))
ep_list = list(np.linspace(0.1, 1, 5, dtype = float))
gamma = list(np.linspace(0.01, 0.1, 5, dtype = float))
degree = [2, 3]

params_SVR = dict( kernel = kernel, C = C_list, epsilon = ep_list, gamma = gamma, degree = degree )

# %%
# Scatter plot
c_val = 100
svr_lin = SVR(kernel='linear', C=c_val)
svr_rbf = SVR(kernel='rbf', C=c_val, gamma=0.01)
svr_poly = SVR(kernel='poly', C=c_val, degree=2)

SVR_Linear = svr_lin.fit(X_train,Y_train).predict(X_test)
SVR_Rbf = svr_rbf.fit(X_train,Y_train).predict(X_test)
SVR_Poly = svr_poly.fit(X_train,Y_train).predict(X_test)

plt.scatter(np.arange(len(Y_train)),Y_train, edgecolors='b', s=2)
plt.scatter(np.arange(len(Y_test)),Y_test, edgecolors='g', s=2)
plt.scatter(np.arange(len(SVR_Linear)),SVR_Linear, edgecolors='y', s=2)
plt.scatter(np.arange(len(SVR_Rbf)),SVR_Rbf, edgecolors='g', s=2)
plt.scatter(np.arange(len(SVR_Poly)),SVR_Poly, edgecolors='r', s=2)
plt.show()

# %% [markdown]
# #### RandomizedSearchCV() -> (a)

# %%
for EST in regression:
    model = regression[EST]
    if (EST == 'LR'):
        params = params_LR
    else:
        params = params_SVR
    grid_rand = RandomizedSearchCV( estimator=model, n_jobs = 1, 
                                    verbose = 10,
                                    cv = 4,
                                    scoring = 'neg_mean_squared_error',
                                    param_distributions = params )
    grid_rand_result = grid_rand.fit(X_train, Y_train)
# Out:
# Fitting 4 folds for each of 4 candidates, totalling 16 fits
# [CV 1/4; 1/4] START fit_intercept=True, normalize=True..........................
# [CV 1/4; 1/4] END fit_intercept=True, normalize=True;, score=-534.384 total time=   0.0s
# [CV 2/4; 1/4] START fit_intercept=True, normalize=True..........................
# [CV 2/4; 1/4] END fit_intercept=True, normalize=True;, score=-808.010 total time=   0.0s
# [CV 3/4; 1/4] START fit_intercept=True, normalize=True..........................
# [CV 3/4; 1/4] END fit_intercept=True, normalize=True;, score=-1626.168 total time=   0.0s
# [CV 4/4; 1/4] START fit_intercept=True, normalize=True..........................
# [CV 4/4; 1/4] END fit_intercept=True, normalize=True;, score=-3101.402 total time=   0.0s
# [CV 1/4; 2/4] START fit_intercept=True, normalize=False.........................
# [CV 1/4; 2/4] END fit_intercept=True, normalize=False;, score=-534.384 total time=   0.0s
# [CV 2/4; 2/4] START fit_intercept=True, normalize=False.........................
# [CV 2/4; 2/4] END fit_intercept=True, normalize=False;, score=-808.010 total time=   0.0s
# [CV 3/4; 2/4] START fit_intercept=True, normalize=False.........................
# [CV 3/4; 2/4] END fit_intercept=True, normalize=False;, score=-1626.168 total time=   0.0s
# [CV 4/4; 2/4] START fit_intercept=True, normalize=False.........................
# [CV 4/4; 2/4] END fit_intercept=True, normalize=False;, score=-3101.402 total time=   0.0s
# [CV 1/4; 3/4] START fit_intercept=False, normalize=True.........................
# [CV 1/4; 3/4] END fit_intercept=False, normalize=True;, score=-9790.403 total time=   0.0s
# [CV 2/4; 3/4] START fit_intercept=False, normalize=True.........................
# [CV 2/4; 3/4] END fit_intercept=False, normalize=True;, score=-1734.164 total time=   0.0s
# [CV 3/4; 3/4] START fit_intercept=False, normalize=True.........................
# [CV 3/4; 3/4] END fit_intercept=False, normalize=True;, score=-7267.370 total time=   0.0s
# [CV 4/4; 3/4] START fit_intercept=False, normalize=True.........................
# [CV 4/4; 3/4] END fit_intercept=False, normalize=True;, score=-20596.397 total time=   0.0s
# [CV 1/4; 4/4] START fit_intercept=False, normalize=False........................
# [CV 1/4; 4/4] END fit_intercept=False, normalize=False;, score=-9790.403 total time=   0.0s
# [CV 2/4; 4/4] START fit_intercept=False, normalize=False........................
# [CV 2/4; 4/4] END fit_intercept=False, normalize=False;, score=-1734.164 total time=   0.0s
# [CV 3/4; 4/4] START fit_intercept=False, normalize=False........................
# [CV 3/4; 4/4] END fit_intercept=False, normalize=False;, score=-7267.370 total time=   0.0s
# [CV 4/4; 4/4] START fit_intercept=False, normalize=False........................
# [CV 4/4; 4/4] END fit_intercept=False, normalize=False;, score=-20596.397 total time=   0.0s
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# [CV 1/4; 1/10] START C=37.575, degree=2, epsilon=0.775, gamma=0.1, kernel=poly..
# [CV 1/4; 1/10] END C=37.575, degree=2, epsilon=0.775, gamma=0.1, kernel=poly;, score=-1097.354 total time=   0.0s
# [CV 2/4; 1/10] START C=37.575, degree=2, epsilon=0.775, gamma=0.1, kernel=poly..
# [CV 2/4; 1/10] END C=37.575, degree=2, epsilon=0.775, gamma=0.1, kernel=poly;, score=-1025.535 total time=   0.0s
# [CV 3/4; 1/10] START C=37.575, degree=2, epsilon=0.775, gamma=0.1, kernel=poly..
# [CV 3/4; 1/10] END C=37.575, degree=2, epsilon=0.775, gamma=0.1, kernel=poly;, score=-325.490 total time=   0.0s
# [CV 4/4; 1/10] START C=37.575, degree=2, epsilon=0.775, gamma=0.1, kernel=poly..
# [CV 4/4; 1/10] END C=37.575, degree=2, epsilon=0.775, gamma=0.1, kernel=poly;, score=-4700.192 total time=   0.0s
# [CV 1/4; 2/10] START C=0.1, degree=3, epsilon=0.1, gamma=0.0325, kernel=poly....
# [CV 1/4; 2/10] END C=0.1, degree=3, epsilon=0.1, gamma=0.0325, kernel=poly;, score=-2250.088 total time=   0.0s
# [CV 2/4; 2/10] START C=0.1, degree=3, epsilon=0.1, gamma=0.0325, kernel=poly....
# [CV 2/4; 2/10] END C=0.1, degree=3, epsilon=0.1, gamma=0.0325, kernel=poly;, score=-844.950 total time=   0.0s
# [CV 3/4; 2/10] START C=0.1, degree=3, epsilon=0.1, gamma=0.0325, kernel=poly....
# [CV 3/4; 2/10] END C=0.1, degree=3, epsilon=0.1, gamma=0.0325, kernel=poly;, score=-1061.992 total time=   0.0s
# [CV 4/4; 2/10] START C=0.1, degree=3, epsilon=0.1, gamma=0.0325, kernel=poly....
# [CV 4/4; 2/10] END C=0.1, degree=3, epsilon=0.1, gamma=0.0325, kernel=poly;, score=-6750.293 total time=   0.0s
# [CV 1/4; 3/10] START C=112.525, degree=3, epsilon=0.775, gamma=0.1, kernel=linear
# [CV 1/4; 3/10] END C=112.525, degree=3, epsilon=0.775, gamma=0.1, kernel=linear;, score=-1213.019 total time=   0.1s
# [CV 2/4; 3/10] START C=112.525, degree=3, epsilon=0.775, gamma=0.1, kernel=linear
# [CV 2/4; 3/10] END C=112.525, degree=3, epsilon=0.775, gamma=0.1, kernel=linear;, score=-638.533 total time=   0.0s
# [CV 3/4; 3/10] START C=112.525, degree=3, epsilon=0.775, gamma=0.1, kernel=linear
# [CV 3/4; 3/10] END C=112.525, degree=3, epsilon=0.775, gamma=0.1, kernel=linear;, score=-1683.414 total time=   0.0s
# [CV 4/4; 3/10] START C=112.525, degree=3, epsilon=0.775, gamma=0.1, kernel=linear
# [CV 4/4; 3/10] END C=112.525, degree=3, epsilon=0.775, gamma=0.1, kernel=linear;, score=-3042.762 total time=   0.0s
# [CV 1/4; 4/10] START C=0.1, degree=3, epsilon=0.775, gamma=0.0775, kernel=rbf...
# [CV 1/4; 4/10] END C=0.1, degree=3, epsilon=0.775, gamma=0.0775, kernel=rbf;, score=-2046.412 total time=   0.0s
# [CV 2/4; 4/10] START C=0.1, degree=3, epsilon=0.775, gamma=0.0775, kernel=rbf...
# [CV 2/4; 4/10] END C=0.1, degree=3, epsilon=0.775, gamma=0.0775, kernel=rbf;, score=-712.910 total time=   0.0s
# [CV 3/4; 4/10] START C=0.1, degree=3, epsilon=0.775, gamma=0.0775, kernel=rbf...
# [CV 3/4; 4/10] END C=0.1, degree=3, epsilon=0.775, gamma=0.0775, kernel=rbf;, score=-933.505 total time=   0.0s
# [CV 4/4; 4/10] START C=0.1, degree=3, epsilon=0.775, gamma=0.0775, kernel=rbf...
# [CV 4/4; 4/10] END C=0.1, degree=3, epsilon=0.775, gamma=0.0775, kernel=rbf;, score=-6509.953 total time=   0.0s
# [CV 1/4; 5/10] START C=75.05, degree=2, epsilon=1.0, gamma=0.0325, kernel=linear
# [CV 1/4; 5/10] END C=75.05, degree=2, epsilon=1.0, gamma=0.0325, kernel=linear;, score=-1160.304 total time=   0.0s
# [CV 2/4; 5/10] START C=75.05, degree=2, epsilon=1.0, gamma=0.0325, kernel=linear
# [CV 2/4; 5/10] END C=75.05, degree=2, epsilon=1.0, gamma=0.0325, kernel=linear;, score=-638.898 total time=   0.0s
# [CV 3/4; 5/10] START C=75.05, degree=2, epsilon=1.0, gamma=0.0325, kernel=linear
# [CV 3/4; 5/10] END C=75.05, degree=2, epsilon=1.0, gamma=0.0325, kernel=linear;, score=-1659.878 total time=   0.0s
# [CV 4/4; 5/10] START C=75.05, degree=2, epsilon=1.0, gamma=0.0325, kernel=linear
# [CV 4/4; 5/10] END C=75.05, degree=2, epsilon=1.0, gamma=0.0325, kernel=linear;, score=-3069.378 total time=   0.0s
# [CV 1/4; 6/10] START C=0.1, degree=3, epsilon=0.775, gamma=0.1, kernel=poly.....
# [CV 1/4; 6/10] END C=0.1, degree=3, epsilon=0.775, gamma=0.1, kernel=poly;, score=-2211.319 total time=   0.0s
# [CV 2/4; 6/10] START C=0.1, degree=3, epsilon=0.775, gamma=0.1, kernel=poly.....
# [CV 2/4; 6/10] END C=0.1, degree=3, epsilon=0.775, gamma=0.1, kernel=poly;, score=-823.660 total time=   0.0s
# [CV 3/4; 6/10] START C=0.1, degree=3, epsilon=0.775, gamma=0.1, kernel=poly.....
# [CV 3/4; 6/10] END C=0.1, degree=3, epsilon=0.775, gamma=0.1, kernel=poly;, score=-1066.789 total time=   0.0s
# [CV 4/4; 6/10] START C=0.1, degree=3, epsilon=0.775, gamma=0.1, kernel=poly.....
# [CV 4/4; 6/10] END C=0.1, degree=3, epsilon=0.775, gamma=0.1, kernel=poly;, score=-6752.377 total time=   0.0s
# [CV 1/4; 7/10] START C=112.525, degree=3, epsilon=0.325, gamma=0.05500000000000001, kernel=rbf
# [CV 1/4; 7/10] END C=112.525, degree=3, epsilon=0.325, gamma=0.05500000000000001, kernel=rbf;, score=-516.359 total time=   0.0s
# [CV 2/4; 7/10] START C=112.525, degree=3, epsilon=0.325, gamma=0.05500000000000001, kernel=rbf
# [CV 2/4; 7/10] END C=112.525, degree=3, epsilon=0.325, gamma=0.05500000000000001, kernel=rbf;, score=-846.120 total time=   0.0s
# [CV 3/4; 7/10] START C=112.525, degree=3, epsilon=0.325, gamma=0.05500000000000001, kernel=rbf
# [CV 3/4; 7/10] END C=112.525, degree=3, epsilon=0.325, gamma=0.05500000000000001, kernel=rbf;, score=-455.071 total time=   0.0s
# [CV 4/4; 7/10] START C=112.525, degree=3, epsilon=0.325, gamma=0.05500000000000001, kernel=rbf
# [CV 4/4; 7/10] END C=112.525, degree=3, epsilon=0.325, gamma=0.05500000000000001, kernel=rbf;, score=-2984.522 total time=   0.0s
# [CV 1/4; 8/10] START C=150.0, degree=2, epsilon=0.55, gamma=0.0775, kernel=rbf..
# [CV 1/4; 8/10] END C=150.0, degree=2, epsilon=0.55, gamma=0.0775, kernel=rbf;, score=-591.346 total time=   0.0s
# [CV 2/4; 8/10] START C=150.0, degree=2, epsilon=0.55, gamma=0.0775, kernel=rbf..
# [CV 2/4; 8/10] END C=150.0, degree=2, epsilon=0.55, gamma=0.0775, kernel=rbf;, score=-893.248 total time=   0.0s
# [CV 3/4; 8/10] START C=150.0, degree=2, epsilon=0.55, gamma=0.0775, kernel=rbf..
# [CV 3/4; 8/10] END C=150.0, degree=2, epsilon=0.55, gamma=0.0775, kernel=rbf;, score=-325.191 total time=   0.0s
# [CV 4/4; 8/10] START C=150.0, degree=2, epsilon=0.55, gamma=0.0775, kernel=rbf..
# [CV 4/4; 8/10] END C=150.0, degree=2, epsilon=0.55, gamma=0.0775, kernel=rbf;, score=-3186.000 total time=   0.0s
# [CV 1/4; 9/10] START C=112.525, degree=3, epsilon=0.775, gamma=0.01, kernel=rbf.
# [CV 1/4; 9/10] END C=112.525, degree=3, epsilon=0.775, gamma=0.01, kernel=rbf;, score=-977.639 total time=   0.0s
# [CV 2/4; 9/10] START C=112.525, degree=3, epsilon=0.775, gamma=0.01, kernel=rbf.
# [CV 2/4; 9/10] END C=112.525, degree=3, epsilon=0.775, gamma=0.01, kernel=rbf;, score=-954.894 total time=   0.0s
# [CV 3/4; 9/10] START C=112.525, degree=3, epsilon=0.775, gamma=0.01, kernel=rbf.
# [CV 3/4; 9/10] END C=112.525, degree=3, epsilon=0.775, gamma=0.01, kernel=rbf;, score=-872.675 total time=   0.0s
# [CV 4/4; 9/10] START C=112.525, degree=3, epsilon=0.775, gamma=0.01, kernel=rbf.
# [CV 4/4; 9/10] END C=112.525, degree=3, epsilon=0.775, gamma=0.01, kernel=rbf;, score=-3291.962 total time=   0.0s
# [CV 1/4; 10/10] START C=150.0, degree=2, epsilon=0.325, gamma=0.0325, kernel=poly
# [CV 1/4; 10/10] END C=150.0, degree=2, epsilon=0.325, gamma=0.0325, kernel=poly;, score=-1007.874 total time=   0.0s
# [CV 2/4; 10/10] START C=150.0, degree=2, epsilon=0.325, gamma=0.0325, kernel=poly
# [CV 2/4; 10/10] END C=150.0, degree=2, epsilon=0.325, gamma=0.0325, kernel=poly;, score=-1128.653 total time=   0.0s
# [CV 3/4; 10/10] START C=150.0, degree=2, epsilon=0.325, gamma=0.0325, kernel=poly
# [CV 3/4; 10/10] END C=150.0, degree=2, epsilon=0.325, gamma=0.0325, kernel=poly;, score=-215.444 total time=   0.0s
# [CV 4/4; 10/10] START C=150.0, degree=2, epsilon=0.325, gamma=0.0325, kernel=poly
# [CV 4/4; 10/10] END C=150.0, degree=2, epsilon=0.325, gamma=0.0325, kernel=poly;, score=-5547.844 total time=   0.0s

# %% [markdown]
# #### RandomizedCV() -> (b)

# %%
# Show Best Parameters for both models
print('Best params: ',grid_rand_result.best_params_)
print('Best score: ', grid_rand_result.best_score_)
# Out:
# Best params:  {'kernel': 'rbf', 'gamma': 0.05500000000000001, 'epsilon': 0.325, 'degree': 3, 'C': 112.525}
# Best score:  -1200.5179071275438

# %%
# Show Score for each parameter combination for both model
means = grid_rand_result.cv_results_['mean_test_score']
stds = grid_rand_result.cv_results_['std_test_score']
params = grid_rand_result.cv_results_['params']
data_zipped = zip(means, stds, params)

# for mean, stdev, param in data_zipped:
    # print("%f (%f) with: %r" % (mean, stdev, param))

data_linear = [{'means': means[i], 'stds': stds[i]} for i in range(len(params)) if params[i]['kernel'] == 'linear' ]
data_rbf = [{'means': means[i], 'stds': stds[i]} for i in range(len(params)) if params[i]['kernel'] == 'rbf' ]
data_poly = [{'means': means[i], 'stds': stds[i]} for i in range(len(params)) if params[i]['kernel'] == 'poly' ]
data_merged = data_linear + data_rbf + data_poly

# %%
df_linear = pd.DataFrame(data=data_linear)
df_linear.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df_rbf = pd.DataFrame(data=data_rbf)
df_rbf.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df_poly = pd.DataFrame(data=data_poly)
df_poly.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df_poly = pd.DataFrame(data=data_merged)
df_poly.plot.bar()
# Out:
# <AxesSubplot:>
