# %% [markdown]
# #### Import Data

# %%
import pandas as pd
import numpy as np         

import seaborn as sns
sns.set_theme(style="whitegrid")

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/churn_data_st.csv', sep=",")
df
# Out:
#       customerID  gender  SeniorCitizen  tenure  ServiceCount        Contract  \
# 0     7590-VHVEG  Female              0       1             2  Month-to-month
# 1     5575-GNVDE    Male              0      34             4        One year
# 2     3668-QPYBK    Male              0       2             4  Month-to-month
# 3     7795-CFOCW    Male              0      45             4        One year
# 4     9237-HQITU  Female              0       2             2  Month-to-month
# ...          ...     ...            ...     ...           ...             ...
# 7038  6840-RESVB    Male              0      24             8        One year
# 7039  2234-XADUH  Female              0      72             7        One year
# 7040  4801-JZAZL  Female              0      11             2  Month-to-month
# 7041  8361-LTMKD    Male              1       4             3  Month-to-month
# 7042  3186-AJIEK    Male              0      66             7        Two year
#
# ...

# %%
df
# Out:
#       customerID  gender  SeniorCitizen  tenure  ServiceCount        Contract  \
# 0     7590-VHVEG  Female              0       1             2  Month-to-month
# 1     5575-GNVDE    Male              0      34             4        One year
# 2     3668-QPYBK    Male              0       2             4  Month-to-month
# 3     7795-CFOCW    Male              0      45             4        One year
# 4     9237-HQITU  Female              0       2             2  Month-to-month
# ...          ...     ...            ...     ...           ...             ...
# 7038  6840-RESVB    Male              0      24             8        One year
# 7039  2234-XADUH  Female              0      72             7        One year
# 7040  4801-JZAZL  Female              0      11             2  Month-to-month
# 7041  8361-LTMKD    Male              1       4             3  Month-to-month
# 7042  3186-AJIEK    Male              0      66             7        Two year
#
# ...

# %%
df.drop(columns='customerID', inplace=True)
df
# Out:
#       gender  SeniorCitizen  tenure  ServiceCount        Contract  \
# 0     Female              0       1             2  Month-to-month
# 1       Male              0      34             4        One year
# 2       Male              0       2             4  Month-to-month
# 3       Male              0      45             4        One year
# 4     Female              0       2             2  Month-to-month
# ...      ...            ...     ...           ...             ...
# 7038    Male              0      24             8        One year
# 7039  Female              0      72             7        One year
# 7040  Female              0      11             2  Month-to-month
# 7041    Male              1       4             3  Month-to-month
# 7042    Male              0      66             7        Two year
#
#      PaperlessBilling  MonthlyCharges  TotalCharges Churn
# 0                 Yes           29.85         29.85    No
# ...

# %%
df.info()

"""
df['TotalCharges'] have null
"""
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   tenure            7043 non-null   int64
#  3   ServiceCount      7043 non-null   int64
#  4   Contract          7043 non-null   object
#  5   PaperlessBilling  7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7016 non-null   float64
#  8   Churn             7043 non-null   object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 495.3+ KB
# "\ndf['TotalCharges'] have null\n"

# %%
sns.boxplot(data=df['TotalCharges'], palette="Blues")
# Out:
# <AxesSubplot:>

# %%
"""
Fill na - df['TotalCharges'] with median
"""

df['TotalCharges'].fillna(value=df['TotalCharges'].median(), inplace=True)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6983 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            6983 non-null   object
#  1   SeniorCitizen     6983 non-null   int64
#  2   tenure            6983 non-null   int64
#  3   ServiceCount      6983 non-null   int64
#  4   Contract          6983 non-null   object
#  5   PaperlessBilling  6983 non-null   object
#  6   MonthlyCharges    6983 non-null   float64
#  7   TotalCharges      6983 non-null   float64
#  8   Churn             6983 non-null   object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 545.5+ KB

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  ServiceCount  MonthlyCharges  TotalCharges
# count    6983.000000  6983.000000   6983.000000     6983.000000   6983.000000
# mean        0.162967    32.640699      5.448804       65.001489   2298.461421
# std         0.369362    24.491253      1.961585       30.033025   2261.904558
# min         0.000000     0.000000      1.000000       18.250000     18.800000
# 25%         0.000000     9.000000      4.000000       36.025000    419.375000
# 50%         0.000000    29.000000      6.000000       70.450000   1410.250000
# 75%         0.000000    56.000000      7.000000       89.950000   3809.375000
# max         1.000000    72.000000      9.000000      118.750000   8684.800000

# %% [markdown]
# #### Remove High Variable Correlation

# %%
columns = df[['tenure','ServiceCount','MonthlyCharges','TotalCharges']]
columns
# Out:
#       tenure  ServiceCount  MonthlyCharges  TotalCharges
# 0          1             2           29.85         29.85
# 1         34             4           56.95       1889.50
# 2          2             4           53.85        108.15
# 3         45             4           42.30       1840.75
# 4          2             2           70.70        151.65
# ...      ...           ...             ...           ...
# 7038      24             8           84.80       1990.50
# 7039      72             7          103.20       7362.90
# 7040      11             2           29.60        346.45
# 7041       4             3           74.40        306.60
# 7042      66             7          105.65       6844.50
#
# [6983 rows x 4 columns]

# %%
columns.corr()
# Out:
#                   tenure  ServiceCount  MonthlyCharges  TotalCharges
# tenure          1.000000      0.513522        0.240886      0.822427
# ServiceCount    0.513522      1.000000        0.047256      0.445337
# MonthlyCharges  0.240886      0.047256        1.000000      0.648383
# TotalCharges    0.822427      0.445337        0.648383      1.000000

# %%
# sns.heatmap(columns.corr(), annot=True, vmin=-1, vmax=1)
sns.heatmap(columns.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
lower = pd.DataFrame(np.tril(columns.corr(), -1), columns=columns.corr().columns)
lower
# Out:
#      tenure  ServiceCount  MonthlyCharges  TotalCharges
# 0  0.000000      0.000000        0.000000           0.0
# 1  0.513522      0.000000        0.000000           0.0
# 2  0.240886      0.047256        0.000000           0.0
# 3  0.822427      0.445337        0.648383           0.0

# %%
sns.heatmap(lower, annot=True)
# Out:
# <AxesSubplot:>

# %%
to_drop = [column for column in lower if any(lower[column] > 0.6)]
# to_drop
df.drop(to_drop, inplace=True, axis=1)
df
# Out:
#       gender  SeniorCitizen  ServiceCount        Contract PaperlessBilling  \
# 0     Female              0             2  Month-to-month              Yes
# 1       Male              0             4        One year               No
# 2       Male              0             4  Month-to-month              Yes
# 3       Male              0             4        One year               No
# 4     Female              0             2  Month-to-month              Yes
# ...      ...            ...           ...             ...              ...
# 7038    Male              0             8        One year              Yes
# 7039  Female              0             7        One year              Yes
# 7040  Female              0             2  Month-to-month              Yes
# 7041    Male              1             3  Month-to-month              Yes
# 7042    Male              0             7        Two year              Yes
#
#       TotalCharges Churn
# 0            29.85    No
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen  ServiceCount  TotalCharges
# count    6983.000000   6983.000000   6983.000000
# mean        0.162967      5.448804   2298.461421
# std         0.369362      1.961585   2261.904558
# min         0.000000      1.000000     18.800000
# 25%         0.000000      4.000000    419.375000
# 50%         0.000000      6.000000   1410.250000
# 75%         0.000000      7.000000   3809.375000
# max         1.000000      9.000000   8684.800000

# %% [markdown]
# #### Remove Variable with High p-value from Chi-square

# %%
columns = df[['Churn']]
columns
# Out:
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [6983 rows x 1 columns]

# %%
columns['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
columns['Churn'].value_counts()
# Out:
# No     5144
# Yes    1839
# Name: Churn, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
# variables = df[['gender', 'Contract', 'PaperlessBilling']]
columns['Churn'] = label_encoder.fit_transform(columns['Churn'])
columns['gender'] = label_encoder.fit_transform(df['gender'])
columns['Contract'] = label_encoder.fit_transform(df['Contract'])
columns['PaperlessBilling'] = label_encoder.fit_transform(df['PaperlessBilling'])
# Out:
# /var/folders/06/x0cz6tx13kvc8_9kk8nptn600000gn/T/ipykernel_81466/1496443121.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns['Churn'] = label_encoder.fit_transform(columns['Churn'])
# /var/folders/06/x0cz6tx13kvc8_9kk8nptn600000gn/T/ipykernel_81466/1496443121.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns['gender'] = label_encoder.fit_transform(df['gender'])
# /var/folders/06/x0cz6tx13kvc8_9kk8nptn600000gn/T/ipykernel_81466/1496443121.py:4: SettingWithCopyWarning:
# ...

# %%
columns
# Out:
#       Churn  gender  Contract  PaperlessBilling
# 0         0       0         0                 1
# 1         0       1         1                 0
# 2         1       1         0                 1
# 3         0       1         1                 0
# 4         1       0         0                 1
# ...     ...     ...       ...               ...
# 7038      0       1         1                 1
# 7039      0       0         1                 1
# 7040      0       0         0                 1
# 7041      1       1         0                 1
# 7042      0       1         2                 1
#
# [6983 rows x 4 columns]

# %%
outputs = columns[['Churn']]
variables = columns[['gender', 'Contract', 'PaperlessBilling']]

# %%
outputs
# Out:
#       Churn
# 0         0
# 1         0
# 2         1
# 3         0
# 4         1
# ...     ...
# 7038      0
# 7039      0
# 7040      0
# 7041      1
# 7042      0
#
# [6983 rows x 1 columns]

# %%
variables
# Out:
#       gender  Contract  PaperlessBilling
# 0          0         0                 1
# 1          1         1                 0
# 2          1         0                 1
# 3          1         1                 0
# 4          0         0                 1
# ...      ...       ...               ...
# 7038       1         1                 1
# 7039       0         1                 1
# 7040       0         0                 1
# 7041       1         0                 1
# 7042       1         2                 1
#
# [6983 rows x 3 columns]

# %%
from sklearn.feature_selection import chi2
chi_table = chi2(variables, outputs)
chi_table
# Out:
# (array([1.69032850e-01, 1.09997055e+03, 1.01928373e+02]),
#  array([6.80972779e-001, 3.35186442e-241, 5.75660495e-024]))

# %%
p_value = chi_table[1]
p_value = pd.DataFrame(np.tril(p_value, -1), columns=variables.columns)
p_value
# Out:
#      gender       Contract  PaperlessBilling
# 0  0.000000   0.000000e+00               0.0
# 1  0.680973   0.000000e+00               0.0
# 2  0.680973  3.351864e-241               0.0

# %%
to_drop = [column for column in p_value if any(p_value[column] > 0.05)]
to_drop
# Out:
# ['gender']

# %%
variables.drop(to_drop, inplace=True, axis=1)
# Out:
# /var/folders/06/x0cz6tx13kvc8_9kk8nptn600000gn/T/ipykernel_81466/1322070880.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   variables.drop(to_drop, inplace=True, axis=1)

# %%
variables
# Out:
#       Contract  PaperlessBilling
# 0            0                 1
# 1            1                 0
# 2            0                 1
# 3            1                 0
# 4            0                 1
# ...        ...               ...
# 7038         1                 1
# 7039         1                 1
# 7040         0                 1
# 7041         0                 1
# 7042         2                 1
#
# [6983 rows x 2 columns]

# %%
df.drop(labels=['Churn', 'gender', 'Contract', 'PaperlessBilling'], axis=1, inplace=True)
df = df.join([variables, outputs])
df
# Out:
#       SeniorCitizen  ServiceCount  TotalCharges  Contract  PaperlessBilling  \
# 0                 0             2         29.85         0                 1
# 1                 0             4       1889.50         1                 0
# 2                 0             4        108.15         0                 1
# 3                 0             4       1840.75         1                 0
# 4                 0             2        151.65         0                 1
# ...             ...           ...           ...       ...               ...
# 7038              0             8       1990.50         1                 1
# 7039              0             7       7362.90         1                 1
# 7040              0             2        346.45         0                 1
# 7041              1             3        306.60         0                 1
# 7042              0             7       6844.50         2                 1
#
#       Churn
# 0         0
# 1         0
# 2         1
# ...

# %%
df['SeniorCitizen'].value_counts()
# Out:
# 0    5845
# 1    1138
# Name: SeniorCitizen, dtype: int64
